# %% [markdown]
# <a href="https://colab.research.google.com/github/AdnanTIF-0064/praktikum-struktur-data-SMT-2/blob/main/pertemuan_6_sorting_s2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BUBBLE SORT

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())  # Menggunakan copy agar data asli tidak berubah

print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# SELECTION SORT

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())

print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# INSERTION SORT

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())

print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# MERGE SORT

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1

    return arr


# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())

print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# QUICK SORT

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr

    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]

    return quick_sort(left) + middle + quick_sort(right)


# Contoh penggunaan
data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())

print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)

# %% [markdown]
# TUGAS REKOMENDASI FILM BERDASARKAN RATING

# %%
def selection_sort(arr, key):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j][key] > arr[min_index][key]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

n = int(input("berapa film yang ingin anda masukkan: "))

data_film = []

for i in range(n):
  print(f"\nfilm ke-{i+1}")
  judul = input("judul film: ")
  rating = float(input("berikan rating anda: "))
  views = int(input("jumlah pemutaran film: "))

  data_film.append({
      "judul": judul,
      "rating": rating,
      "views": views
  })

# Pilih kriteria sorting
print("\nPilih kriteria sorting:")
print("1. Rating tertinggi")
print("2. Jumlah pemutaran terbanyak")
pilihan = input("Masukkan pilihan (1/2): ")

if pilihan == "1":
    hasil = selection_sort(data_film, "rating")
    print("\nRekomendasi berdasarkan rating tertinggi:")
elif pilihan == "2":
    hasil = selection_sort(data_film, "views")
    print("\nRekomendasi berdasarkan jumlah pemutaran terbanyak:")
else:
    print("Pilihan tidak valid!")
    exit()

for item in hasil:
  print(f"{item['judul']} | rating: {item['rating']} | views: {item['views']}")
# Out:
# berapa film yang ingin anda masukkan: 2
#
# film ke-1
# judul film: nfjkgfdjk
# berikan rating anda: 123
# jumlah pemutaran film: 32
#
# film ke-2
# judul film: cnbjfdnbj
# berikan rating anda: 123
# jumlah pemutaran film: 34
#
# Pilih kriteria sorting:
# 1. Rating tertinggi
# 2. Jumlah pemutaran terbanyak
# Masukkan pilihan (1/2): 2
#
# Rekomendasi berdasarkan jumlah pemutaran terbanyak:
# cnbjfdnbj | rating: 123.0 | views: 34
# nfjkgfdjk | rating: 123.0 | views: 32
