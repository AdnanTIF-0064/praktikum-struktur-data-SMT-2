# %% [markdown]
# <a href="https://colab.research.google.com/github/AdnanTIF-0064/praktikum-struktur-data-SMT-2/blob/main/pertemuan_4_queue_s2s.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# QUEUE DENGAN LIST

# %%
queue = []

# append() function to push element in the stack
queue.append("i")
queue.append("a")
queue.append("e")
queue.append("u")
queue.append("o")

print("stack ditambahkan")
print(queue)

# pop() function to pop element from stack in  LIFO order
print("\nelement from the stack: ")
print(queue.pop())
print(queue.pop())
print(queue.pop())

print("\nstack after element are popped:")
print(queue)
# Out:
# stack ditambahkan
# ['i', 'a', 'e', 'u', 'o']
#
# element from the stack:
# o
# u
# e
#
# stack after element are popped:
# ['i', 'a']

# %% [markdown]
# QUEUE DENGAN COLLECTIONS DEQUE

# %%
from collections import deque

queue = deque()

# append() function to enqueue element in the queue
queue.append("a")
queue.append("i")
queue.append("u")
queue.append("e")
queue.append("o")

print("queue ditambahkan")
print(queue)

# pop() function to pop element from stack in  LIFO order
print("\nelement dequeue from the queue: ")
print(queue.popleft())
print(queue.popleft())
print(queue.popleft())

print("\nqueue after element are popped:")
print(queue)
# Out:
# queue ditambahkan
# deque(['a', 'i', 'u', 'e', 'o'])
#
# element dequeue from the queue:
# a
# i
# u
#
# queue after element are popped:
# deque(['e', 'o'])

# %% [markdown]
# QUEUE DENGAN QUEUE.QUEUE

# %%
from queue import Queue

qu = Queue(maxsize=5)

# qsize() show the number of element in the queue
print(qu.qsize())

# put() function to enqueue element in the queue
qu.put("a")
qu.put("i")
qu.put("u")
qu.put("e")
qu.put("o")

print("Full", qu.full())
print("Size", qu.qsize())

# get() function to pop element from stack in Lifo order
print("\nelement from the stack: ")
print(qu.get())
print(qu.get())
print(qu.get())

print("\nEmpty: ", qu.empty())
print("Full: ", qu.full())
# Out:
# 0
# Full True
# Size 5
#
# element from the stack:
# a
# i
# u
#
# Empty:  False
# Full:  False

# %% [markdown]
# QUEUE DENGAN SINGLE LINKED LIST

# %%
class Queue:
    def __init__(self):
        self.queue = list()

    # Insert method to add element
    def addtoqu(self, dataval):
        if dataval not in self.queue:
            self.queue.insert(0, dataval)
            return True
        return False

    # Pop method to remove element
    def removefromq(self):
        if len(self.queue) > 0:
            return self.queue.pop()
        return ("No elements in Queue!")

    def size(self):
        return len(self.queue)


TheQueue = Queue()

print(TheQueue.addtoqu("Jan"))
print(TheQueue.addtoqu("Feb"))
print(TheQueue.addtoqu("March"))
print(TheQueue.addtoqu("April"))

print(TheQueue.size())

print(TheQueue.removefromq())
print(TheQueue.removefromq())

print(TheQueue.size())
# Out:
# True
# True
# True
# True
# 4
# Jan
# Feb
# 2
